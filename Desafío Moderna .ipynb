# %%
import matplotlib.pyplot as plt
import sympy as sym
import numpy as np
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score
import qexpy as q

# %%
h=1
c=1
G=1.16e-5
q=0.3028
mw = 80
Z=1
g = G*mw**2*8/np.sqrt(2)
g
# Out:
# 0.41996485948231427

# %%
V = lambda r:  -(g**2)*(np.exp(-mw*r)/r)  + (Z*(q**2))/r

# %%
r = np.linspace(4e-3,0.5e-1,1000)
y = V(r)
plt.plot(r,y,label="μ=1, Z=1",color="blue")
plt.xlabel("r")
plt.ylabel("V(r)")
plt.legend()

# %%
lennard=lambda r: -(g**2)*(1/r**6)  + (Z*(q**2))/r**12

# %%
rs=np.linspace(0.2e-12,1e-12,100)
ys2=lennard(rs)

# %%
plt.plot(rs,ys2)

# %%
V=lambda r: -(g**2)*(np.exp(-mu*r)/r)  + (Z*(q**2))/r

# %%
lennard2=lambda x: -1/x**6 +1/x**12

x=np.linspace(0.9,3)
y=lennard2(x)

# %%
plt.plot(x,y)

# %%
prueba=lambda r: -np.exp(-r)/r + 1/r

px=np.linspace(0,60)
py=prueba(px)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_8260\180933382.py:1: RuntimeWarning: divide by zero encountered in divide
#   prueba=lambda r: -np.exp(-r)/r + 1/r
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_8260\180933382.py:1: RuntimeWarning: invalid value encountered in add
#   prueba=lambda r: -np.exp(-r)/r + 1/r

# %%
plt.plot(px,py)
